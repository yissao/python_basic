# %%
##### pandas
import pandas as pd

verificar = 'unidentified.txt' #nome do arquivo para colocar na variavel teste
#colspecs = [(0,32),(32,34),(34,-1)]
#historico = pd.read_fwf('Historico.txt',colspecs = colspecs, names=['hashmd5sum','sp','arquivo'] )
colspecs = [(0,-1)]
# verificarduplicado = pd.read_fwf(verificar, colspecs = colspecs, names=['caminho'])
verificarduplicado = pd.read_csv(verificar, header=None, encoding='utf-8')
display(verificarduplicado)

# historico.hashmd5sum.duplicated()
# historico.hashmd5sum.duplicated().sum() # soma de duplicados
# (~historico.hashmd5sum.duplicated()).sum() # soma de NAO duplicados
# historico.loc[historico.duplicated(), :] # lista duplicados
# historico.drop_duplicates(inplace=True) # remove duplicados do dataframe, sem o inplace cria novo dataframe

verificarduplicado.duplicated().sum()

limpo= verificarduplicado.drop_duplicates()
display(limpo)
limpo.to_csv('listax.txt', index=False, header=False)
# Out:
#                                                      0
# 0    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 1    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 2    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 3    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 4    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# ..                                                 ...
# 425  D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 426  D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 427  D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 428  D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 429  D:\~delete\reddit\WhatsApp_Business_Images\uni...
#
# [430 rows x 1 columns]
#                                                      0
# 0    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 1    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 2    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# 3    D:\~delete\reddit\WhatsApp_Business_Images\uni...
# ...
